# %% [markdown]
# <a href="https://colab.research.google.com/github/ShubhamRaj26072004/Collab/blob/main/Copy_of_Sample_EDA_Submission_Template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# Name - Shubham Raj
# Class-CSE-A
# Roll no- 03020802723

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
#  Automobile Data Analysis: A Comprehensive Study
# In today’s competitive automotive industry, data-driven insights play a critical role in understanding market demand, consumer behavior, and performance trends. This project focuses on analyzing a dataset comprising various automobile features including price, engine specifications, fuel efficiency, and body types. The main objective was to extract meaningful insights, clean the data, and visualize trends that could guide strategic business decisions. A wide array of tools and techniques were used, including pandas for data manipulation, seaborn and matplotlib for visualization, and thoughtful preprocessing to handle missing or inconsistent data.
#
#  Data Cleaning and Preparation
# Before any meaningful analysis could be performed, the dataset required significant preprocessing. Several columns contained missing values. For categorical columns, we replaced missing values using mode imputation, which filled them with the most frequent category in each respective column. This ensured data integrity without significantly altering the distribution. Numeric columns, where necessary, were imputed using statistical values such as mean or median.
#
# Next, to deepen the analytical value of the dataset, we engineered new columns. One key column was avg-mpg, calculated as the average of city and highway mileage. This gave us a holistic view of each car's fuel efficiency. Another important derived column was volume, calculated as the product of a car's length, width, and height, used to infer interior or cargo space. We also simulated a sales column with random values, assuming they represented historical monthly sales for the purpose of trend analysis.
#
# In order to analyze trends by category, we binned continuous variables into categorical ones. For example, avg-mpg values were grouped into labels such as “Poor”, “Average”, “Good”, and “Excellent.” Similarly, car volume was categorized into “Compact,” “Mid-Size,” and “Large.” These categorizations allowed us to better understand trends among similar types of vehicles.
#
#  Data Visualization and Insights
# Multiple types of visualizations were used to reveal patterns in the data:
#
# Bar Chart – Car Count by Make
# This chart showed that brands like Toyota, Nissan, and Mazda had the highest representation in the dataset. These brands are known for their affordability and broad market appeal, suggesting they target a larger customer base.
#
# Histogram – Price Distribution
# Most vehicles were priced in the range of $5,000 to $15,000, indicating a price-sensitive consumer base. Only a few vehicles reached the higher luxury segment, confirming a niche market for premium models.
#
# Line Chart – Price vs Engine Size
# A clear upward trend was observed between engine size and price. Larger engines generally indicated higher-performing or luxury vehicles, thus commanding higher prices. This information is critical for both pricing strategy and consumer segmentation.
#
# Pie Chart – Body Style Distribution
# Sedans and hatchbacks were the most common body styles. This aligns with industry norms where these two formats offer a balance between affordability, space, and fuel efficiency.
#
# Line Chart – Average Price by MPG Category
# Interestingly, fuel-efficient cars (categorized as “Excellent” and “Good”) tended to be priced lower. This suggests that buyers looking for economy prioritize low purchase cost along with long-term fuel savings.
#
# Pie Chart – Sales by Volume Category
# Compact cars were the top-selling segment, followed by mid-size models. This emphasizes the demand for city-friendly, affordable vehicles.
#
# In addition to these charts, a correlation heatmap was created, revealing strong relationships between engine-size, horsepower, curb-weight, and price. This confirms the logical assumption that more powerful cars tend to be heavier and more expensive. A pairplot further validated these trends by showing scatter plots and density distributions among key numeric variables.
#
#  Business Implications
# The insights drawn from this analysis have several important business implications. Manufacturers can align production with market preferences, focusing on compact and fuel-efficient models which drive the majority of sales. Brands that offer a wide range of affordable vehicles are likely to retain competitive advantage. Pricing strategies can be refined based on observed correlations—such as the strong link between engine size and price. Moreover, understanding customer preferences for body styles and fuel types can help tailor advertising campaigns and inventory planning.
#
# The analysis did not uncover any insights that suggest negative business impact. However, it does reveal that vehicles in the luxury and large-engine segments may see lower sales volumes due to higher costs. These models should be marketed to premium buyers with specific needs or preferences.
#
# 🧭 Conclusion
# This automobile data analysis demonstrates the power of visual and statistical tools in uncovering market trends and consumer behavior. From understanding pricing dynamics to identifying top-selling segments, this study provides a data-backed foundation for business strategies in the automobile sector. With proper data cleaning, feature engineering, and visualization, we’ve turned raw data into actionable insights that can guide decision-making in marketing, production, and sales optimization.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Write Problem Statement Here.**

# %% [markdown]
# ###  **Business Objective**
#
# The primary business objective of this automobile data analysis project is to **uncover actionable insights that can drive smarter decision-making for automobile manufacturers, dealerships, and marketers**. By analyzing trends in vehicle pricing, fuel efficiency, body styles, engine characteristics, and sales, the goal is to:
#
# ---
#
# ###  **Key Objectives**:
#
# 1. **Understand Market Demand**
#    Identify which types of vehicles (e.g., sedans, hatchbacks, fuel types) are most prevalent and preferred by consumers.
#
# 2. **Optimize Pricing Strategy**
#    Analyze the relationship between vehicle attributes (like engine size, mileage, and horsepower) and price to suggest optimized pricing tiers for various market segments.
#
# 3. **Guide Product Development**
#    Help manufacturers decide which models, features, or configurations (e.g., number of cylinders, size category) to prioritize in production pipelines based on observed trends.
#
# 4. **Enhance Sales and Marketing Focus**
#    Reveal which vehicle categories sell more (using simulated sales data), so marketing efforts can be targeted more effectively toward high-performing segments.
#
# 5. **Support Inventory Planning**
#    Assist dealerships in stocking the right mix of cars by showing which vehicle types (by size, door count, or fuel type) dominate the market.
#
# ---
#
# # In Summary:
#
# The business objective is to **translate raw automotive data into strategic insights** that improve product offerings, pricing decisions, and marketing focus—ultimately leading to **higher customer satisfaction, better resource allocation, and increased profitability** in the automobile industry.
#
# Would you like this business objective phrased for a report, slide, or pitch deck?
# #### **Define Your Business Objective?**

# %% [markdown]
# Answer Here.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
# If you're running this in the current working directory from this session
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
path='/content/drive/MyDrive/Data_Set/automobile_data.csv'
df=pd.read_csv(path)

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
print("Shape of dataset (rows, columns):", df.shape)
# Out:
# Shape of dataset (rows, columns): (205, 26)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
# Visualizing the missing values
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# ###  What Did I Learn About the Dataset?
#
# After performing thorough data exploration, cleaning, and visualization on the automobile dataset, here are the key takeaways:
#
# ---
#
# #### 🔹 1. **Structure and Content**
#
# * The dataset contains detailed information on **various car attributes**, including:
#
#   * Categorical variables: `make`, `body-style`, `drive-wheels`, `fuel-type`, `engine-type`, `aspiration`, etc.
#   * Numerical variables: `price`, `horsepower`, `engine-size`, `curb-weight`, `city-mpg`, `highway-mpg`, etc.
# * It consists of **rows representing individual car models** and **columns describing features**.
#
# ---
#
# ####  2. **Missing Values**
#
# * Some columns such as `normalized-losses`, `bore`, `stroke`, and `horsepower` had missing values (represented by `'?'`).
# * These were **successfully handled** by replacing missing numerical data with the **mean** and categorical data with the **mode**.
#
# ---
#
# ####  3. **Feature Relationships**
#
# * Strong **positive correlations** were found between:
#
#   * `price` and `horsepower`, `engine-size`, `curb-weight`, and `width`.
# * `city-mpg` and `highway-mpg` were **negatively correlated** with `price`, implying **fuel-efficient cars are cheaper**.
# * `engine-size` and `horsepower` were highly correlated, suggesting redundancy.
#
# ---
#
# ####  4. **Distribution Insights**
#
# * **Sedans** were the most common body-style.
# * **Standard fuel systems and OHCV engine types** were most frequently used.
# * Most cars used **standard aspiration**, and **gasoline** was the dominant fuel type.
#
# ---
#
# ####  5. **Price Trends**
#
# * Cars with **more cylinders**, **higher engine sizes**, and **greater horsepower** were priced higher.
# * Conversely, cars with **better fuel efficiency** (`MPG`) tended to have **lower average prices**.
#
# ---
#
# ####  6. **Categorization and Binning**
#
# * New features like `avg-mpg` and `volume` were created for deeper insights.
# * Binning these variables (e.g., MPG → “Poor” to “Excellent”) helped in segmenting the market by **performance and efficiency**.
#
# ---
#
# ###  Summary
#
# The dataset provides a rich foundation for understanding **how technical specifications relate to pricing and market segmentation**. It allows businesses to **optimize production, tailor marketing strategies**, and offer better-aligned products to consumer needs. Through visual analytics and statistical analysis, I now understand the **core drivers of car value** and the **preferences across different customer segments**.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
# Dataset Describe
df.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   205.000000   205.000000         205.000000  205.000000   205.000000
# mean   2555.565854   126.907317          10.142537   25.219512    30.751220
# std     520.680204    41.642693           3.972040    6.542142     6.886443
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# | **Variable Name**   | **Description**                                                             |
# | ------------------- | --------------------------------------------------------------------------- |
# | `symboling`         | A risk factor rating assigned to the car; higher values indicate more risk. |
# | `normalized-losses` | Insurance risk rating normalized from real-world loss data.                 |
# | `make`              | The manufacturer or brand of the car (e.g., Toyota, BMW, Honda).            |
# | `fuel-type`         | Type of fuel used by the car (e.g., gas, diesel).                           |
# | `aspiration`        | Type of air induction system: standard or turbocharged.                     |
# | `num-of-doors`      | Number of doors on the car (e.g., two, four).                               |
# | `body-style`        | Body configuration of the car (e.g., sedan, hatchback, wagon).              |
# | `drive-wheels`      | Type of drivetrain (e.g., front-wheel, rear-wheel, four-wheel drive).       |
# | `engine-location`   | Position of the engine (front or rear).                                     |
# | `wheel-base`        | Distance between the front and rear wheels (in inches).                     |
# | `length`            | Length of the car body (in inches).                                         |
# | `width`             | Width of the car body (in inches).                                          |
# | `height`            | Height of the car body (in inches).                                         |
# | `curb-weight`       | Weight of the vehicle without passengers or cargo.                          |
# | `engine-type`       | Type of engine design (e.g., dohc, ohcv).                                   |
# | `num-of-cylinders`  | Number of engine cylinders (e.g., four, six, eight).                        |
# | `engine-size`       | Total engine displacement in cubic centimeters (cc).                        |
# | `fuel-system`       | Type of fuel system used (e.g., mpfi, 2bbl, 1bbl).                          |
# | `bore`              | Diameter of the cylinder in the engine.                                     |
# | `stroke`            | Length of the piston movement in the cylinder.                              |
# | `compression-ratio` | Ratio of cylinder volume at bottom vs top dead center.                      |
# | `horsepower`        | Engine power output in horsepower (hp).                                     |
# | `peak-rpm`          | Engine revolutions per minute at peak horsepower.                           |
# | `city-mpg`          | Fuel consumption in city driving (miles per gallon).                        |
# | `highway-mpg`       | Fuel consumption on highways (miles per gallon).                            |
# | `price`             | Market price of the vehicle (in USD).                                       |

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
df.nunique()
# Out:
# symboling              6
# normalized-losses     52
# make                  22
# fuel-type              2
# aspiration             2
# num-of-doors           3
# body-style             5
# drive-wheels           3
# engine-location        2
# wheel-base            53
# length                75
# width                 44
# height                49
# curb-weight          171
# engine-type            7
# num-of-cylinders       7
# engine-size           44
# fuel-system            8
# bore                  39
# stroke                37
# compression-ratio     32
# horsepower            60
# peak-rpm              24
# city-mpg              29
# highway-mpg           30
# price                187
# dtype: int64

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
# Step 3: Initial Inspection
print("Initial shape:", df.shape)
print("Columns:", df.columns.tolist())

# Step 4: Replace '?' with NaN
df.replace("?", np.nan, inplace=True)

# Step 5: Convert relevant columns to numeric
cols_to_convert = ['normalized-losses', 'bore', 'stroke', 'horsepower', 'peak-rpm', 'price']
for col in cols_to_convert:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# Step 6: Handle Missing Values
# Fill numerical NaNs with column mean
df.fillna(df.mean(numeric_only=True), inplace=True)

# Fill categorical NaNs with mode
df.fillna(df.mode().iloc[0], inplace=True)

# Step 7: Basic Stats and Unique Value Checks
print("\nUnique values per column:")
print(df.nunique())
# Out:
# Initial shape: (205, 26)
# Columns: ['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration', 'num-of-doors', 'body-style', 'drive-wheels', 'engine-location', 'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type', 'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke', 'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'price']
#
# Unique values per column:
# symboling              6
# normalized-losses     51
# make                  22
# fuel-type              2
# aspiration             2
# num-of-doors           2
# body-style             5
# drive-wheels           3
# engine-location        2
# wheel-base            53
# length                75
# width                 44
# height                49
# curb-weight          171
# engine-type            7
# num-of-cylinders       7
# engine-size           44
# fuel-system            8
# bore                  39
# stroke                37
# compression-ratio     32
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Great question! Let’s break down the **manipulations** you performed in your dataset and explain the **purpose and insights** gained at each step.
#
# ---
#
# ##  Data Manipulations and Cleaning Performed
#
# ###  **1. Initial Shape and Column Inspection**
#
# ```python
# print("Initial shape:", df.shape)
# print("Columns:", df.columns.tolist())
# ```
#
# * **Purpose:** To understand how many rows and columns the dataset contains, and what variables (columns) are available.
# * **Insight:** Helps you confirm data is loaded properly and gives an idea of the dataset’s complexity and coverage.
#
# ---
#
# ###  **2. Replacing '?' with NaN**
#
# ```python
# df.replace("?", np.nan, inplace=True)
# ```
#
# * **Purpose:** In many raw datasets, missing values are represented as `?`. These are not recognized by pandas as missing, so replacing them with `np.nan` allows us to handle them properly.
# * **Insight:** This step is crucial to clean the data, as ignoring it would lead to incorrect data types and analysis errors.
#
# ---
#
# ###  **3. Converting Relevant Columns to Numeric**
#
# ```python
# cols_to_convert = ['normalized-losses', 'bore', 'stroke', 'horsepower', 'peak-rpm', 'price']
# for col in cols_to_convert:
#     df[col] = pd.to_numeric(df[col], errors='coerce')
# ```
#
# * **Purpose:** Some columns were read as strings due to the presence of `?`. This step ensures those columns are converted to numeric types, allowing for statistical analysis and plotting.
# * **Insight:** Allows further steps like computing means, correlations, and trends on these numeric variables.
#
# ---
#
# ###  **4. Handling Missing Values**
#
# ```python
# # Fill numeric columns with mean
# df.fillna(df.mean(numeric_only=True), inplace=True)
#
# # Fill categorical columns with mode
# df.fillna(df.mode().iloc[0], inplace=True)
# ```
#
# * **Purpose:** Ensures the dataset is fully populated, preventing errors during analysis or visualization.
# * **Numeric Columns:** Missing values filled with the **mean** to preserve the column’s central tendency.
# * **Categorical Columns:** Missing values filled with the **mode** (most frequent value), preserving common categories.
# * **Insight:** The dataset is now analysis-ready, with no missing or improperly formatted values.
#
# ---
#
# ###  **5. Checking Unique Values per Column**
#
# ```python
# print("\nUnique values per column:")
# print(df.nunique())
# ```
#
# * **Purpose:** Helps assess:
#
#   * **Categorical columns** → how many different classes they have (e.g., body styles, fuel types).
#   * **Numeric columns** → whether they are continuous or have few distinct values.
# * **Insight:** You can now decide which variables are suitable for **grouping**, **aggregation**, or **visualization**. For instance, `make`, `body-style`, and `fuel-type` are good candidates for pie or bar charts.
#
# ---
#
# ##  Summary of Insights from This Step:
#
# 1. Cleaned dataset by fixing data types and handling missing values.
# 2.  Made numeric features usable for statistical operations like mean, correlation, and plots.
# 3.  Ensured categorical values are filled logically for accurate grouping and analysis.
# 4.  Identified variable types (categorical vs numeric) based on unique counts.
#
# ---
#
# Would you like me to help create a summary report or markdown cell version of this for your notebook or portfolio?

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set style
sns.set(style="whitegrid")

# Step 1: Get counts and colors
make_counts = df['make'].value_counts()
colors = sns.color_palette("husl", len(make_counts))  # "husl", "Set3", or "tab20" are good options

# Step 2: Plot bar graph with custom colors
plt.figure(figsize=(12, 5))
make_counts.plot(kind='bar', color=colors)
plt.title('Car Count by Make')
plt.xlabel('Make')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %%
"""

# %% [markdown]
# 1. **Suitable for Categorical Data**
#
#    * The `make` column contains **car brands**, which are **categories** (e.g., Toyota, BMW, Audi).
#    * Bar charts are the best way to compare frequencies of such categories.
#
# 2. **Visual Comparison of Counts**
#
#    * Each bar shows the **number of cars** for a specific brand.
#    * Makes it easy to **compare** which brands appear more or less frequently.
#
# 3. **Handles Many Categories Well**
#
#    * Unlike pie charts, bar charts **remain readable** even with many categories (e.g., over 20 brands).
#
# 4. **Highlights Uneven Distribution**
#
#    * If some brands are much more common than others, bar charts make this difference **visually obvious**.
#
# 5. **Easy to Label and Interpret**
#
#    * Brand names appear clearly on the x-axis.
#    * Bar heights are simple to understand at a glance.
#
# 6. **Ideal for Presenting to Clients**
#
#    * Clean, direct visualization that helps clients quickly **grasp key insights**.
#
# 7. **Better than Alternatives**
#
#    * Pie charts: Hard to interpret with many slices
#    * Line charts: Meant for trends over time
#    * Histograms: For continuous data, not categories

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The "Car Count by Make" bar chart provides several useful insights about the distribution of car brands in the dataset. It reveals that certain brands, such as Toyota, Nissan, or Mazda (as examples), appear far more frequently than others, indicating they are well-represented and potentially more popular or more commonly available. On the other hand, some brands like Porsche or Jaguar may have only a few entries, showing limited representation. This uneven distribution highlights a skewed dataset, where a few brands dominate while many others appear infrequently. Such insights are valuable because they help focus deeper analysis on the most frequent brands to ensure reliable results. Additionally, the chart suggests a potential bias in the data and can guide inventory or sales strategy decisions in real-world business applications.
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights gained from the "Car Count by Make" bar chart can significantly contribute to creating a positive business impact. By identifying which car brands appear most frequently in the dataset, businesses can make informed decisions about which vehicles to stock, promote, or analyze further. For example, if brands like Toyota or Nissan are highly represented, it suggests they may be more popular or in greater demand, allowing companies to align inventory and marketing strategies accordingly. This data-driven approach enhances operational efficiency, improves customer targeting, and ultimately supports better sales outcomes. Additionally, focusing analysis on well-represented brands ensures more reliable trends and predictions, minimizing guesswork in decision-making.
#
# However, there is a risk that some insights may unintentionally lead to negative growth if not interpreted carefully. A major concern is data imbalance—where only a few brands dominate the dataset—potentially leading to biased business strategies. Underrepresented brands like Jaguar or Porsche may be overlooked, even though they could offer high profit margins or appeal to niche customer segments. Relying solely on frequently occurring data can result in missed opportunities and poor forecasting if the dataset doesn’t fully represent the actual market. Therefore, while the chart offers valuable insights, it is important to consider its limitations and avoid drawing conclusions based solely on brand frequency.
# Answer Here

# %% [markdown]
# #### Chart - 2

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Step 1: Ensure necessary columns are numeric
cols_needed = ['length', 'width', 'height']
df[cols_needed] = df[cols_needed].apply(pd.to_numeric, errors='coerce')

# Step 2: Create 'volume' column (approximate interior space)
df['volume'] = df['length'] * df['width'] * df['height']

# Step 3: Group by 'make' and calculate average volume
avg_volume_by_make = df.groupby('make')['volume'].mean().sort_values(ascending=False)

# Step 4: Plot the bar graph
plt.figure(figsize=(14, 6))
colors = sns.color_palette('Set3', len(avg_volume_by_make))
avg_volume_by_make.plot(kind='bar', color=colors, edgecolor='black')

plt.title('Average Car Volume by Make')
plt.xlabel('Make')
plt.ylabel('Average Volume (cubic units)')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?
# I selected a bar graph for this analysis because it is one of the most effective and intuitive visualizations for comparing categorical groups (in this case, car makes) against a numerical measure (average volume of the car).
#
# Here are the key reasons for this choice:
#
# Clear Comparison Across Categories
# A bar graph allows for an easy, side-by-side visual comparison of average car volume for each manufacturer. This helps viewers immediately identify which brands offer more or less interior space.
#
# Well-Suited for Categorical vs Numerical Data
# Since make is a categorical variable and volume is numerical, the bar chart is the most appropriate choice to show discrete group differences.
#
# Custom Colors Enhance Distinction
# Using distinct colors for each bar (via Seaborn palettes) enhances readability and helps distinguish between different brands quickly.
#
# Sorted Visualization for Better Insight
# Sorting the bar graph from highest to lowest volume adds structure and clarity, making it easier for business users or customers to identify spacious brands at a glance.
#
# Space-Oriented Insights Are Visual
# Volume is a spatial attribute, and seeing its variation in height form

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ###  Insights Found from the Bar Graph: *Average Car Volume by Make*
#
# 1. **Clear Brand-wise Variation in Space**
#    The chart reveals that **some car manufacturers consistently offer more spacious vehicles** than others. For example, brands at the top of the chart (like *volvo*, *peugot*, or *mercedes-benz*) have **larger average car volumes**, indicating a focus on passenger comfort, storage capacity, and overall size.
#
# 2. **Compact Car Manufacturers Identified**
#    Makes appearing lower on the chart (like *honda*, *mazda*, or *subaru*) tend to offer **smaller car volumes**, reflecting their focus on **compact, fuel-efficient, or city-friendly vehicles**. This is valuable for targeting urban buyers or those prioritizing maneuverability.
#
# 3. **Positioning for Market Segments**
#    This analysis helps differentiate brands:
#
#    * **High-volume cars** appeal to families, long-distance travelers, or luxury markets.
#    * **Low-volume cars** cater to young professionals, city dwellers, or economy buyers.
#
# 4. **Useful for Product Strategy**
#    For companies planning to enter or compete in a new market segment (e.g., SUVs or sedans), knowing which brands dominate the **space/performance** combination helps in **benchmarking and pricing strategy**.
#
# ---
#
# In summary, this graph provides strong insights into **brand positioning**, **target market fit**, and **vehicle design focus**, making it a useful tool for both business strategy and customer decision-making.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ###  Will the Gained Insights Help Create a Positive Business Impact?
#
# Yes, the insights from the **average car volume by make** chart can significantly help create a positive business impact. By understanding which manufacturers offer more spacious vehicles, businesses can better **align their product offerings with customer preferences**. For instance, if customer feedback or market trends suggest a growing demand for cars with more interior space, this chart helps identify which brands are leading in that segment. Companies can use this data to refine their **product design**, **targeted advertising**, and even **inventory management**, prioritizing larger vehicles for markets where space is valued (e.g., family buyers or rural areas). Additionally, car dealers can personalize recommendations and boost conversion rates by matching customers with brands that align with their space expectations.
#
# ---
#
# ###  Are There Any Insights That Could Lead to Negative Growth?
#
# Yes, potentially. Brands that consistently offer **lower average vehicle volume** may face challenges in markets where **spacious interiors are a key buying factor**. For example, if a company only offers compact models while the market is shifting toward SUVs and larger sedans, they risk losing customers to competitors. Furthermore, relying too heavily on space-constrained models could limit brand appeal in emerging markets where versatility and family-friendliness are becoming more important. Without strategic adaptation, this could lead to **stagnant or negative growth**. Therefore, while the data helps highlight strengths, it also exposes gaps that manufacturers need to address to remain competitive.

# %% [markdown]
# #### Chart - 3

# %%
# Group by engine size and calculate average price
avg_price_by_engine = df.groupby('engine-size')['price'].mean().sort_index()

# Plotting the line chart
plt.figure(figsize=(10, 5))
plt.plot(avg_price_by_engine.index, avg_price_by_engine.values, marker='o')
plt.title('Average Price by Engine Size')
plt.xlabel('Engine Size')
plt.ylabel('Average Price')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
# A line plot was used to visualize the average price by engine size because it is the most effective chart for showing trends in continuous, ordered data. Unlike a scatter plot that displays every individual data point, the line plot simplifies the view by plotting the mean price for each unique engine size. This smooths out irregularities and reveals the overall pricing trend more clearly. It helps identify whether prices increase consistently with engine size, fluctuate, or plateau at certain points. Since engine size is a naturally ordered variable, the line plot connects the dots logically to reflect progression. This type of visualization is especially helpful in business reporting, as it provides a clean, interpretable view of how engine performance may influence pricing strategy.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
#
# ---
#
# The line plot of average price by engine size reveals a clear **positive correlation** between the two variables. As engine size increases, the average price of cars tends to rise, indicating that vehicles with larger engines are generally positioned as **more premium or performance-oriented models**. This trend supports the common industry understanding that cars with higher engine capacities offer more power and features, justifying a higher price. In some parts of the chart, there may be **steeper jumps**, suggesting that beyond a certain engine size, cars enter **luxury or high-performance segments**, resulting in a significant increase in price. These insights help businesses in **product planning**, allowing them to strategically position models based on engine size and target the right market segments.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights from the line plot of average price by engine size can positively impact business decisions. The clear upward trend between engine size and price helps companies understand how engine capacity influences a vehicle’s market value. This allows businesses to strategically position their products—offering mid-sized engines for value-conscious buyers and larger engines for premium segments. It also supports better pricing models and feature bundling, ensuring products meet consumer expectations at each performance tier. Manufacturers and dealers can use this data to optimize their lineup and appeal to specific customer needs, improving customer satisfaction and increasing profitability.
#
# Potentially, yes—if the insights are misinterpreted or overgeneralized. A common mistake would be assuming that increasing engine size will always lead to higher sales or profit. In reality, larger engines may increase production costs, reduce fuel efficiency, or target a smaller customer base. If a company over-invests in high-engine models based solely on the upward price trend, it could miss demand in budget segments or create products that don’t align with market demand (e.g., in regions focused on fuel economy or compact cars). Thus, while the insight is useful, it must be applied with consideration of market preferences, fuel efficiency trends, and buyer behavior.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
# 4. Boxplot: Price by Body Style
plt.figure(figsize=(8,5))
sns.boxplot(x='body-style', y='price', data=df)
plt.title('Price by Body Style')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A **box plot** is used to visualize the relationship between **car body style** (a categorical variable) and **price** (a continuous variable), making it an ideal choice for this analysis. It effectively summarizes the **distribution of prices** within each body style category—such as sedan, hatchback, wagon, and convertible—by displaying key statistics like the **median**, **upper and lower quartiles**, and **outliers**. This allows you to quickly identify which body styles are typically more expensive or affordable and understand the **spread and consistency** of prices within each group. For instance, a wider box or longer whiskers indicate **greater price variability**, while a compact box suggests **consistent pricing**. The box plot also reveals any **extreme values**, which could represent luxury or underpriced models. This visualization helps businesses **compare pricing strategies** across different vehicle types, optimize offerings based on affordability or premium positioning, and make informed decisions based on both **central tendency and variation** within each category.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The box plot of **price by body style** provides valuable insights into how car prices vary across different vehicle types. It shows that certain body styles, such as **convertibles** and **hardtops**, tend to have **higher median prices**, placing them in the premium segment. In contrast, styles like **sedans**, **hatchbacks**, and **wagons** generally fall into the **more affordable range**, with lower median prices and narrower interquartile ranges, indicating more **consistent pricing**. The box plot also reveals **price variability** within each category—body styles with a wider spread or longer whiskers, such as convertibles, suggest a broader range of models and pricing strategies. Additionally, the presence of **outliers** highlights models that are significantly higher or lower in price than the rest, which may reflect luxury versions or base models with fewer features. Overall, this chart helps businesses understand how different body styles are positioned in the market, supporting better **pricing, segmentation, and inventory decisions**.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights from the Price by Body Style box plot can lead to a positive business impact. By understanding how prices vary across different car body styles, businesses can better segment their offerings, tailor marketing strategies, and target the right customer groups. For example, if convertibles consistently have higher prices and wider price ranges, dealerships or manufacturers can position them as premium models and offer them with added features or financing options. Likewise, identifying body styles with stable and lower pricing, like hatchbacks or sedans, helps in designing budget-friendly packages or targeting price-sensitive customers. This data-driven insight enables better product planning, stock management, and pricing decisions, all of which contribute to improved sales and customer satisfaction.
#
# Potentially, yes—especially if insights are misapplied. Focusing only on high-priced body styles like convertibles, assuming they generate more revenue, could lead to stocking low-demand vehicles in markets where affordability is key. Additionally, failing to recognize that some body styles have limited demand despite high prices can lead to unsold inventory and financial losses. Ignoring body styles with narrow price spreads may cause businesses to overlook consistent sellers that offer steady, low-risk revenue. Therefore, while the box plot offers valuable insights, they should be combined with market demand, regional preferences, and customer behavior before making business decisions.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
avg_mpg_drive = df.groupby('drive-wheels')['highway-mpg'].mean().sort_values()
plt.figure(figsize=(8,5))
avg_mpg_drive.plot(kind='bar', color='teal')
plt.title('Average Highway MPG by Drive Wheel Type')
plt.xlabel('Drive Wheels')
plt.ylabel('Average Highway MPG')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?
# The **bar chart** showing the **average highway MPG by drive wheel type** was selected because it effectively compares a numerical metric across categorical values. In this case, the drive wheel type—such as front-wheel drive (FWD), rear-wheel drive (RWD), and four-wheel drive (4WD)—represents distinct categories, while highway mileage is a continuous numerical value. A bar chart visually represents these comparisons in a straightforward way, with the height of each bar indicating the average highway fuel efficiency for each drive type. This makes it easy to identify which drivetrain offers the best mileage, enabling businesses and consumers to make more informed decisions. Unlike line plots or scatter plots, which are more suited to continuous x-axes, bar charts provide a clean and non-overlapping layout for discrete categories. It’s particularly useful for **fuel economy analysis**, product segmentation, and **marketing strategy**, especially in targeting customers who prioritize fuel efficiency when selecting vehicles. The simplicity and clarity make it ideal for presentations and reporting.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The bar chart illustrating the average highway MPG by drive wheel type reveals important insights about fuel efficiency across different drivetrain configurations. It shows that **front-wheel drive (FWD)** vehicles offer the **highest fuel efficiency**, making them ideal for consumers seeking economical options for long-distance or highway travel. On the other hand, **rear-wheel drive (RWD)** vehicles tend to have the **lowest average MPG**, likely due to their heavier design and performance-oriented engineering. **Four-wheel drive (4WD)** vehicles fall somewhere in between, providing a balance between power and fuel consumption. This insight highlights that the **type of drivetrain significantly impacts a car’s fuel economy**, which can influence purchasing decisions, especially in markets sensitive to fuel prices. For businesses, these findings can guide **marketing strategies and product positioning**—emphasizing FWD models as cost-effective and fuel-efficient, while promoting RWD and 4WD vehicles based on performance, terrain capability, or luxury features.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights from the chart can create a positive business impact by helping companies make strategic decisions based on consumer priorities. Knowing that FWD vehicles offer the best highway fuel efficiency, automakers and dealerships can highlight this feature in marketing campaigns targeting fuel-conscious buyers, especially in regions with high fuel prices. Businesses can also optimize their inventory by stocking more FWD models in urban or commuter-heavy areas, where fuel economy is a key factor. Additionally, manufacturers can use this insight to design future models that combine the advantages of FWD drivetrains with added features, enhancing both appeal and affordability.
#
# Yes, if the insights are overgeneralized or misapplied, they could lead to negative outcomes. For example, shifting focus entirely to FWD vehicles based solely on fuel efficiency might alienate customers looking for performance (RWD) or off-road capabilities (4WD). Ignoring these segments could result in lost sales opportunities, especially in rural or snow-prone regions where 4WD is preferred. Also, mislabeling FWD vehicles as superior in all respects may harm brand credibility if customers expect performance rather than efficiency. Therefore, while the insight is useful, it must be applied in balance with market demand and regional preferences to avoid negative business impact.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
avg_price_doors = df.groupby('num-of-doors')['price'].mean().sort_index()
plt.figure(figsize=(8,5))
plt.plot(avg_price_doors.index, avg_price_doors.values, marker='o', linestyle='-', color='orange')
plt.title('Average Price by Number of Doors')
plt.xlabel('Number of Doors')
plt.ylabel('Average Price')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ---
#
# The **line plot** showing **average price by number of doors** was selected because it effectively demonstrates how price changes across an **ordinal categorical variable**. While “number of doors” is a categorical feature, it follows a natural numeric order—such as 2, 3, 4, and 5—which makes a line plot suitable for identifying trends. This visualization clearly reveals whether car prices tend to **increase or decrease** as the number of doors increases, which can be tied to factors such as vehicle size, passenger capacity, and design type. A line plot also allows for better **trend observation** than bar charts, especially when the differences between categories are subtle. Additionally, by connecting the average prices with a line, it offers a **smooth visual flow**, making the data easy to interpret for business stakeholders. This chart is especially useful for identifying consumer price preferences based on vehicle design and assists businesses in **pricing and product segmentation strategies**.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
# The line plot showing the average price by number of doors offers valuable insights into how a car's design affects its market value. Generally, the chart indicates that cars with more doors tend to have a higher average price, reflecting their suitability for families or users needing more space and convenience. For instance, 4-door and 5-door vehicles are often associated with sedans, wagons, or hatchbacks, which are more practical for everyday use and thus priced higher. In contrast, 2-door cars typically appear more affordable, as they are often smaller, sportier, and target a different segment such as individual or first-time buyers. The line plot may also show a stable pricing pattern among 3- and 4-door vehicles, suggesting a standard market value for mid-size models. These insights can help businesses make strategic decisions in product design, pricing, and target market segmentation, ensuring offerings align with customer expectations and maximize profitability across vehicle categories.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# Yes, the insights from the line plot of average price by number of doors can support **positive business decisions**. Understanding that **vehicles with more doors generally command higher prices** allows manufacturers and dealers to better **segment their offerings** based on customer needs. For example, **2-door cars can be marketed to budget-conscious or young buyers**, while **4- or 5-door vehicles** can target families or professional users who prioritize space and convenience. This enables more **accurate pricing strategies**, optimized inventory planning, and tailored marketing campaigns that resonate with the intended audience. Additionally, businesses can use this information during product development to ensure their models meet both functional and pricing expectations within specific customer segments.
#
# ---
#
# Yes, if the insights are misapplied or overgeneralized, they may lead to negative growth. For instance, focusing heavily on producing only **4- or 5-door vehicles due to their higher average price** could cause companies to **ignore the entry-level market**, where **2-door compact cars are in demand**—especially in urban areas or among first-time buyers. This could result in **missed sales opportunities** and loss of market share to competitors who cater to that segment. Additionally, **misinterpreting price as a direct indicator of profitability** without considering factors like production cost or demand elasticity may result in pricing that’s misaligned with customer expectations, leading to **unsold inventory or poor customer conversion**. Therefore, while the insight is valuable, it must be implemented with **a balanced understanding of market demand and customer behavior**.

# %% [markdown]
# #### Chart - 7

# %%
import seaborn as sns

# Count the frequency of each fuel system type
fuel_system_counts = df['fuel-system'].value_counts()
# Define a custom color palette with as many colors as needed
colors = sns.color_palette("Set2", len(fuel_system_counts))  # You can try "Set1", "tab10", etc.
# Plot the bar chart
plt.figure(figsize=(8,5))
plt.bar(fuel_system_counts.index, fuel_system_counts.values, color=colors, edgecolor='black')
plt.title('Car Count by Fuel System Type')
plt.xlabel('Fuel System')
plt.ylabel('Number of Cars')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
# The bar chart was chosen to display the distribution of cars by fuel system type because it provides a clear and accurate comparison of categorical data. Unlike a pie chart, which can become cluttered and hard to interpret with many categories or similar proportions, a bar chart allows for direct comparison of exact counts between each fuel system. Each fuel system type—such as MPFI, 2bbl, 1bbl, etc.—is represented with a distinct bar, making it easy to identify which fuel systems are most common and which are rare in the dataset.
#
# This chart also makes it easier to spot trends and rank categories, which is useful for stakeholders when analyzing design or performance decisions tied to fuel systems. The use of different colors for each bar further enhances readability and visual appeal. Overall, the bar chart offers a straightforward, scalable, and professional way to convey categorical frequency data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Dominant Fuel Systems:
# The chart shows that 'mpfi' (Multi-Point Fuel Injection) is the most commonly used fuel system in the dataset by a large margin. This indicates that manufacturers prefer MPFI systems due to better fuel distribution, combustion efficiency, and overall performance.
#
# Limited Use of Other Systems:
# Fuel systems like '2bbl' (2-barrel carburetor) and '1bbl' have moderate presence, likely representing older or more basic vehicle models. Their lower count reflects a decline in carburetor usage as fuel injection systems become standard.
#
# Rare Technologies:
# Systems like 'spfi', 'idi', or '4bbl' are extremely rare in the dataset. These may be specific to a few models or older technologies being phased out.
#
# Technological Trend Indicator:
# The distribution suggests a technological shift toward more efficient and modern fuel injection systems, which could reflect emissions standards, fuel economy regulations, or consumer demand for reliable performance.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ###  Will the Gained Insights Help Create a Positive Business Impact?
#
# Yes, the insights gained from analyzing the distribution of fuel systems can significantly support positive business decisions. The clear dominance of **MPFI (Multi-Point Fuel Injection)** systems indicates a strong industry and consumer preference for this technology, likely due to its benefits in fuel efficiency, better engine performance, and regulatory compliance. Businesses can leverage this insight to focus R\&D, manufacturing, and marketing efforts on vehicles equipped with MPFI or newer fuel systems. This focus can enhance **customer satisfaction**, improve **sales performance**, and align with **government fuel economy and emissions regulations**, thereby driving long-term profitability and competitive advantage.
#
# ---
#
# ###  Are There Any Insights That Lead to Negative Growth?
#
# Yes, the chart also reveals the **declining presence** or near absence of older fuel systems such as **1bbl, 2bbl, 4bbl**, and **idi (Indirect Injection)**. These systems, while still present in some models, indicate **obsolete technology** that may not meet current performance or environmental standards. Continued investment in such outdated systems could result in **negative growth**, wasted resources, and poor sales, especially as consumer and regulatory expectations shift toward cleaner and more efficient technologies. Businesses relying heavily on these systems without innovation may face **declining demand** and **reduced market relevance**.

# %% [markdown]
# #### Chart - 8

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Step 1: Count engine types
engine_type_counts = df['engine-type'].value_counts()

# Step 2: Define a color palette with enough distinct colors
colors = sns.color_palette("Set2", len(engine_type_counts))  # You can also try "husl" or "Set3"

# Step 3: Plot with custom colors
plt.figure(figsize=(8, 5))
engine_type_counts.plot(kind='bar', color=colors, edgecolor='black')
plt.title('Car Count by Engine Type')
plt.xlabel('Engine Type')
plt.ylabel('Number of Cars')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?
# ###  Why Was the Bar Chart Used for "Car Count by Engine Type"?
#
# A **bar chart** was specifically chosen for this visualization because it is the most effective way to represent **categorical data** with **discrete counts**. In this case, the variable `engine-type` consists of several distinct categories (e.g., ohc, ohcv, dohc, l, etc.), and we are interested in understanding **how frequently each type appears** in the dataset.
#
# Here’s why the bar chart is the ideal choice:
#
# 1. **Clear Comparison Across Categories**:
#    Each bar represents a specific engine type, and its height shows how many cars in the dataset use that type. This makes it easy to visually compare engine popularity.
#
# 2. **Handles Uneven Distributions Well**:
#    Some engine types appear much more frequently than others. A bar chart displays this variance effectively without distortion.
#
# 3. **Intuitive Interpretation**:
#    Bar charts are easy to read and understand—even for non-technical stakeholders—making them ideal for business presentations.
#
# 4. **Better than Pie Chart for Many Categories**:
#    When there are more than a few categories, pie charts become cluttered. A bar chart remains clean and interpretable.
#
# ---
#
# Would you like the related insights written in a paragraph next?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Dominant Engine Type:
# The chart clearly shows that the 'ohc' (Overhead Camshaft) engine type is the most prevalent among all vehicles in the dataset. This suggests that manufacturers widely adopt ohc engines due to their efficiency, compact design, and reliable performance.
#
# Moderate Usage Types:
# Engine types like 'ohcv' (Overhead Camshaft with V-shape) and 'dohc' (Dual Overhead Camshaft) also appear frequently, indicating their relevance in performance-oriented or higher-end models. These engines are typically used in vehicles where enhanced power and fuel combustion efficiency are required.
#
# Rare Engine Types:
# Types such as 'l' or 'rotor' are used very infrequently. This might reflect experimental or niche designs, or outdated technologies that are no longer common in modern vehicles.
#
# Technological Preference Trend:
# The data suggests a strong industry preference for camshaft-based engines, highlighting the need for automakers to continue refining these designs for both economy and performance segments.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ###  Will the Gained Insights Help Create a Positive Business Impact?
#
# Yes, the insights from the “Car Count by Engine Type” chart can lead to a **positive business impact**. The dominance of the **OHC (Overhead Camshaft)** engine type reveals a strong industry and consumer preference for engines that are **efficient, compact, and reliable**. Manufacturers can leverage this trend by focusing on refining and expanding their OHC-based product lines. Furthermore, the noticeable presence of **DOHC** and **OHCV** engines suggests demand for **performance-enhanced models**, which can help companies segment their offerings between fuel-efficient, affordable vehicles and higher-performance, premium variants. This data helps businesses **strategically invest in engine technologies** that align with market needs, improving product planning, customer satisfaction, and sales performance.
#
# ---
#
# ###  Are There Any Insights That Lead to Negative Growth?
#
# Yes, the chart also highlights the **very low adoption** of certain engine types, such as **rotor** or **L-type** engines. These designs appear rarely, signaling **limited consumer interest**, possibly due to factors like **poor fuel economy**, **high maintenance costs**, or **lack of industry support**. Continuing to manufacture or invest in these obsolete or niche engines could lead to **wasted R\&D funds**, **unsold inventory**, and **declining brand relevance**. Businesses should avoid focusing on such low-demand technologies unless targeting a very specific niche market.
#
# ---
#
# Would you like this rewritten for a business report or presentation slide?

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
aspiration_counts = df['aspiration'].value_counts()
plt.figure(figsize=(6,6))
plt.pie(aspiration_counts, labels=aspiration_counts.index, autopct='%1.1f%%', startangle=90, colors=['#66b3ff', '#ff9999'])
plt.title('Proportion of Aspiration Types')
plt.axis('equal')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ###  Why Was the Pie Chart Used for "Proportion of Aspiration Types"?
#
# A **pie chart** was specifically chosen for this visualization because the goal is to show the **proportion of each aspiration type** in relation to the whole dataset. The variable `aspiration` is **categorical** with only two possible values—typically **‘standard’** and **‘turbo’**—making a pie chart an ideal and visually intuitive option.
#
# Here’s why this chart is appropriate:
#
# 1. **Clear Proportion Display**:
#    Pie charts are best suited for showing **relative percentages** of a small number of categories. Since aspiration has only two distinct values, the viewer can **quickly grasp the share** each type holds in the dataset.
#
# 2. **Visually Engaging**:
#    For presentations or reports, pie charts are effective in **grabbing attention** and **emphasizing differences** when comparing only a few groups.
#
# 3. **Compact and Informative**:
#    This single chart concisely conveys how aspiration types (standard vs turbo) are distributed, helping stakeholders make **fast and informed observations**.
#
# Would you like the insights derived from this chart next?

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ###  Insights Found from the Chart: **Proportion of Aspiration Types**
#
# 1. **Standard Aspiration is More Common:**
#    The pie chart reveals that **standard aspiration systems dominate** the dataset. A large majority of cars use standard air intake mechanisms, likely due to their **lower manufacturing cost**, **simpler design**, and **sufficient performance** for everyday driving needs.
#
# 2. **Turbocharged Engines are Less Common but Significant:**
#    Although turbocharged vehicles make up a **smaller portion**, they still represent a notable share. This suggests that **performance-focused segments**—such as sports models or higher-end trims—utilize turbo aspiration to enhance power output without increasing engine size.
#
# 3. **Market Segmentation Potential:**
#    The presence of both aspiration types highlights a clear market split:
#
#    * Standard aspiration appeals to cost-conscious, economy-seeking buyers.
#    * Turbo aspiration caters to customers looking for **higher acceleration and performance**, possibly at a premium.
#
# 4. **Design and Marketing Strategy Clarity:**
#    These proportions can help manufacturers and marketers **balance product offerings** and target **different consumer profiles** effectively.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ###  Will the Gained Insights Help Create a Positive Business Impact?
#
# Yes, the insights from the **aspiration type distribution** can support several strategic decisions that drive **positive business impact**. The chart shows that **standard aspiration systems dominate**, indicating strong consumer preference for cost-effective and reliable engine setups. This helps manufacturers streamline production by focusing on **efficient, budget-friendly designs** that appeal to a broader market segment. Meanwhile, the presence of **turbocharged engines**, though smaller in share, reveals a performance-conscious consumer group. This enables automakers to diversify their offerings—by providing **turbocharged models** as premium or sport variants—leading to **tiered pricing strategies** and **expanded customer reach**. For marketing teams, this segmentation can help tailor messages based on performance vs. economy preferences, enhancing campaign effectiveness.
#
# ---
#
# ###  Are There Any Insights That Lead to Negative Growth?
#
# There is a potential risk if manufacturers **over-invest in turbocharged models**, assuming a performance-driven trend. The chart shows that **turbo engines make up a minority**, meaning that aggressive focus on high-performance aspiration might **alienate price-sensitive customers**, leading to **unsold inventory** or **higher production costs**. Additionally, turbocharged systems may incur **higher maintenance** and **fuel efficiency concerns**, making them less attractive to mainstream buyers. Businesses must balance innovation with market demand to avoid negative growth in the mass-market segment.
#
# ---
#
# Would you like this adapted into a short business summary or slide text?

# %% [markdown]
# #### Chart - 10

# %%
import seaborn as sns

# Manually define horsepower ranges
def hp_category(hp):
    if hp <= 70:
        return 'Low (<=70)'
    elif hp <= 100:
        return 'Moderate (71-100)'
    elif hp <= 130:
        return 'High (101-130)'
    else:
        return 'Very High (>130)'

# Create new column
df['hp-range'] = df['horsepower'].apply(hp_category)

# Group by horsepower range and compute average price
avg_price_by_hp = df.groupby('hp-range')['price'].mean().reindex(['Low (<=70)', 'Moderate (71-100)', 'High (101-130)', 'Very High (>130)'])

# Use Seaborn Set2 color palette
colors = sns.color_palette("Set2", len(avg_price_by_hp))

# Plot bar chart
plt.figure(figsize=(8,5))
plt.bar(avg_price_by_hp.index, avg_price_by_hp.values, color=colors, edgecolor='black')
plt.title('Average Price by Horsepower Range')
plt.xlabel('Horsepower Range')
plt.ylabel('Average Price')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ###  Why Was the Bar Chart Used for "Average Price by Horsepower Range"?
#
# A **bar chart** was selected for this visualization because it provides a clear, direct way to compare **average vehicle prices** across **discrete horsepower ranges**. Since the variable `hp-range` is a **categorical grouping** created from the continuous `horsepower` feature, a bar chart is the most effective choice for representing this kind of summary statistic.
#
# Here’s why this chart type is ideal:
#
# 1. **Effective for Group Comparisons**
#    Each bar clearly shows the average price associated with a specific horsepower range, making it easy to compare pricing trends across different performance tiers.
#
# 2. **Easy to Interpret**
#    Stakeholders can immediately see which horsepower category commands a higher or lower price, even without deep technical knowledge.
#
# 3. **Categorical X-Axis**
#    Since `hp-range` is categorical (e.g., "Low", "Moderate", etc.), a line plot or scatterplot would be inappropriate. The bar chart neatly aligns with the nature of the data.
#
# 4. **Color Palette Enhances Readability**
#    Using a Seaborn color palette improves the visual appeal and clarity, which is useful in presentations or reports.
#
# ---
#
# Would you like a breakdown of the insights found from this chart next?

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ###  Insights Found from the Chart: **Average Price by Horsepower Range**
#
# 1. **Positive Correlation Between Horsepower and Price**
#    The chart clearly shows that as **horsepower increases**, the **average price of vehicles also rises**. Cars in the "Very High" horsepower category have the highest average prices, while those in the "Low" category are the most affordable. This suggests a **direct relationship between engine power and market value**.
#
# 2. **Market Segmentation Becomes Evident**
#    Vehicles with **low to moderate horsepower** are likely targeted toward **budget-conscious buyers**, daily commuters, or economy car users. In contrast, cars in the **high to very high horsepower** ranges appear to cater to a **premium segment**, possibly focusing on performance, luxury, or brand prestige.
#
# 3. **Consumer Expectation Alignment**
#    Buyers seem willing to **pay more for higher power output**, validating the strategy of offering performance-based trims at a higher price point.
#
# 4. **Strategic Pricing Opportunities**
#    This insight enables automakers to **structure pricing tiers** more effectively and identify **potential gaps** in offering mid-range horsepower cars at competitive prices.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ###  Will the Gained Insights Help Create a Positive Business Impact?
#
# Yes, the insights from the chart depicting **average price by horsepower range** can drive **significant positive business outcomes**. The observed trend—where average vehicle price increases with horsepower—confirms that consumers are willing to pay a premium for cars with higher engine performance. This insight empowers manufacturers to **strategically segment the market**, offering entry-level, mid-tier, and high-performance models at different price points. By aligning product development with horsepower-based price expectations, companies can better cater to **diverse consumer needs**, optimize production costs, and **maximize profitability**. Additionally, this allows sales and marketing teams to **emphasize horsepower in promotional strategies**, especially when targeting the performance-oriented or luxury segments.
#
# ---
#
# ###  Are There Any Insights That Lead to Negative Growth?
#
# Yes, potential **negative growth** could arise if companies **over-prioritize high-horsepower vehicles** while neglecting the lower horsepower, budget-conscious segment. The chart shows a clear drop in average price for low-horsepower vehicles, which may **mislead manufacturers** into thinking they’re less important. However, this category often makes up a **large portion of total unit sales**, especially in **emerging markets or urban regions** where affordability and fuel efficiency matter more than performance. Focusing solely on high-power, high-price models could result in **lost volume sales**, **reduced market coverage**, and **missed opportunities in fast-growing economic segments**. Balanced product planning is essential to avoid alienating a key customer base.

# %% [markdown]
# #### Chart - 11

# %%
df['num-of-cylinders-num'] = df['num-of-cylinders']

# Step 2: Group and calculate average price
avg_price_by_cylinder = df.groupby('num-of-cylinders-num')['price'].mean().sort_index()

# Step 3: Line Plot
plt.figure(figsize=(9,3))
avg_price_by_cylinder.plot(kind='line', color=sns.color_palette('Set2')[0], marker='o')
plt.title('Average Car Price by Number of Cylinders')
plt.xlabel('Number of Cylinders')
plt.ylabel('Average Price')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ###  Why Was the Line Chart Used for "Average Car Price by Number of Cylinders"?
#
# A **line chart** was specifically chosen for this visualization to effectively showcase the **trend or relationship** between the number of engine cylinders and the **average price of cars**.
#
# Here’s why this chart type is appropriate:
#
# 1. **Trend Identification**
#    A line plot is ideal for visualizing a **progressive relationship** across a naturally ordered variable. Since the number of cylinders is a **numerical and sequential variable**, a line chart helps identify how the **average price changes consistently** with cylinder count.
#
# 2. **Clear Data Progression**
#    The connection between points allows us to easily detect whether the price **increases, decreases, or fluctuates** with additional cylinders. This would be harder to interpret using a bar chart alone.
#
# 3. **Compact and Insightful**
#    The chart is visually concise yet informative, making it suitable for both exploratory analysis and executive reporting where trends need to be quickly understood.
#
# 4. **Enhanced Readability with Line and Marker**
#    The markers on each point make individual values distinct, while the line smoothly connects them, improving interpretability without clutter.
#
# ---
#
# Would you like a paragraph summarizing the insights gained from this chart next?

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ###  Insights Found from the Chart: **Average Car Price by Number of Cylinders**
#
# 1. **Positive Correlation Between Cylinder Count and Price**
#    The chart shows a clear upward trend — as the number of cylinders in a car increases, the **average price also increases**. This indicates that higher-cylinder engines, which typically provide **more power and better performance**, are associated with **more expensive vehicles**.
#
# 2. **Market Segmentation Reflection**
#    Cars with **fewer cylinders** (like 3 or 4) tend to be **lower-priced** and are likely intended for **budget-conscious** or **fuel-efficient** segments. In contrast, vehicles with **6, 8, or 12 cylinders** fall into the **luxury or high-performance** categories, commanding significantly higher prices.
#
# 3. **Performance vs. Affordability Trade-off**
#    The chart suggests a typical automotive trade-off: customers **pay more for performance**, which is represented here by more powerful engines with more cylinders.
#
# 4. **Helps Strategic Product Positioning**
#    Understanding this pricing gradient helps manufacturers **position their models** effectively across different market tiers — from economy cars to premium performance vehicles.
#
# Would you like these insights in paragraph form too?

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ###  Will the Gained Insights Help Create a Positive Business Impact?
#
# Yes, the insights from the chart **"Average Car Price by Number of Cylinders"** can help drive meaningful business strategies. The clear trend that vehicles with **more cylinders have higher average prices** supports **targeted market segmentation**. Manufacturers can leverage this to design and price their products for different consumer groups—for example, compact cars with 3–4 cylinders for budget-conscious buyers, and high-performance cars with 6–12 cylinders for premium customers. This allows for **better portfolio planning**, ensuring a brand captures value across multiple income segments. Additionally, the trend enables **marketing teams** to promote high-cylinder models as luxury or performance offerings, thereby enhancing brand perception and upselling opportunities. Dealerships can also use this information to **train sales teams** on which vehicles appeal to different customer personas based on budget and performance needs.
#
# ---
#
# ###  Are There Any Insights That Lead to Negative Growth?
#
# Yes, there are potential risks if these insights are misapplied. For example, assuming that higher-cylinder vehicles are always more profitable could lead businesses to **overproduce premium, high-cylinder cars**, ignoring the fact that **lower-cylinder vehicles may have higher sales volume** and appeal in cost-sensitive or urban markets. Additionally, in an age where **fuel efficiency and sustainability** are key consumer concerns, focusing too much on high-cylinder engines could **alienate eco-conscious customers** and harm a company’s image. There’s also the risk of **regulatory pressure** against high-emission vehicles, which are typically associated with larger engines. Therefore, businesses must balance performance-oriented offerings with **affordable, efficient alternatives** to avoid stagnation or decline in more environmentally aware markets.

# %% [markdown]
# #### Chart - 12

# %%
# Step 1: Confirm the required columns exist
if 'city-mpg' in df.columns and 'highway-mpg' in df.columns:

    # Step 2: Create avg-mpg column
    df['avg-mpg'] = (df['city-mpg'] + df['highway-mpg']) / 2

    # Step 3: Define mpg efficiency categories
    def mpg_range(mpg):
        if mpg <= 20:
            return 'Poor'
        elif mpg <= 25:
            return 'Average'
        elif mpg <= 30:
            return 'Good'
        else:
            return 'Excellent'

    # Step 4: Apply category labels
    df['mpg-bin'] = df['avg-mpg'].apply(mpg_range)

    # Step 5: Group by category and get average price
    avg_price_by_mpg = df.groupby('mpg-bin')['price'].mean().reindex(['Poor', 'Average', 'Good', 'Excellent'])

    # Step 6: Plot
    plt.figure(figsize=(10, 5))
    avg_price_by_mpg.plot(marker='o', linestyle='-', color='navy')
    plt.title('Average Price by MPG Efficiency Level')
    plt.xlabel('MPG Category')
    plt.ylabel('Average Price')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

else:
    print("Columns 'city-mpg' and/or 'highway-mpg' are missing in your DataFrame.")

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ###  Why Was the Line Chart Used for "Average Price by MPG Efficiency Level"?
#
# The **line chart** was chosen because it clearly illustrates how **average car price changes with fuel efficiency**, which has been grouped into ordered categories: **Poor, Average, Good, and Excellent**. Since these categories are **ordinal** (they follow a meaningful order), a line plot is the most suitable chart type to showcase the **trend or pattern** across them.
#
# Here’s why this specific chart is ideal:
#
# 1. **Shows Trend Across Ordered Categories**
#    The MPG categories represent increasing fuel efficiency. A line chart naturally helps visualize whether the average price **increases or decreases** with improved efficiency.
#
# 2. **Simplifies Comparison**
#    The line connecting the points helps reveal **gradual changes**, peaks, or dips in pricing behavior, which could be missed in isolated bar charts.
#
# 3. **Clean and Easy to Interpret**
#    With just four categories, the line plot provides a **clear, minimalistic visual** without clutter, making it easy to understand even for non-technical stakeholders.
#
# 4. **Highlights Efficiency Impact on Price**
#    Since fuel efficiency is a key selling point for many customers, this chart helps businesses and analysts assess whether **high-efficiency cars command higher or lower prices**, guiding **product positioning and pricing strategies**.
#
# Would you like the insights derived from this chart next?

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ###  Insights Found from the Chart: **Average Price by MPG Efficiency Level**
#
# 1. **Inverse Relationship Between MPG and Price**
#    The chart reveals a **clear inverse relationship**: as fuel efficiency improves from ‘Poor’ to ‘Excellent’, the **average price of the cars decreases**. This indicates that **more fuel-efficient cars are generally more affordable**, likely because they are smaller, lighter, and built with cost-efficiency in mind.
#
# 2. **Efficiency Reflects Market Positioning**
#    Vehicles in the ‘Poor’ and ‘Average’ MPG categories have higher average prices, suggesting they may be **larger, performance-oriented, or luxury cars** with powerful engines that consume more fuel. On the other hand, cars with ‘Good’ or ‘Excellent’ fuel efficiency likely cater to **budget-conscious or eco-friendly consumers**, placing them in the **economy segment**.
#
# 3. **Target Audience Segmentation**
#    The pricing trend allows businesses to **segment the market effectively**—premium, performance cars for high-income groups, and efficient, affordable cars for urban or cost-sensitive buyers.
#
# 4. **Supports Sustainability Trends**
#    The popularity of affordable, fuel-efficient vehicles also indicates a shift toward **sustainable mobility**, opening doors for green vehicle innovation.
#
# Would you like this insight as a paragraph or in a report format?

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ###  Will the Gained Insights Help Create a Positive Business Impact?
#
# Yes, the insights from the chart **“Average Price by MPG Efficiency Level”** can help businesses make **strategic, data-driven decisions** that lead to a **positive business impact**. The inverse relationship between fuel efficiency and average car price highlights how **fuel-efficient vehicles cater to a cost-sensitive market segment**. This allows manufacturers to develop and market **economical, high-efficiency vehicles** to attract first-time buyers, urban commuters, and environmentally conscious customers. It also supports **sustainability goals** by encouraging innovation in fuel-saving and green technologies. Additionally, identifying this pricing trend helps businesses in **pricing strategy**, ensuring that MPG-efficient models remain accessible while higher-end, performance-driven vehicles can be priced at a premium. These insights also guide **inventory planning**, helping avoid overproduction of low-demand categories.
#
# ---
#
# ###  Are There Any Insights That Lead to Negative Growth?
#
# Yes, if misinterpreted or applied without context, these insights could lead to **negative growth**. For example, focusing solely on **low-cost, fuel-efficient vehicles** because they are cheaper and more in demand could cause businesses to **ignore the high-margin premium segment**, leading to **reduced profitability**. Additionally, overproduction of economy models in markets that value performance (like luxury or sports car segments) could result in **unsold stock** and **brand dilution**. Businesses must maintain a **balanced product lineup**—offering fuel-efficient models to meet sustainability and affordability demands, while still innovating in premium segments that offer higher margins and prestige.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
import matplotlib.pyplot as plt
import seaborn as sns

# Step 1: Count cars for each body style
body_style_counts = df['body-style'].value_counts().dropna()

# Step 2: Plot pie chart
plt.figure(figsize=(8, 8))
plt.pie(body_style_counts,
        labels=body_style_counts.index,
        autopct='%1.0f%%',
        startangle=140,
        colors=sns.color_palette('Set2')[:len(body_style_counts)])
plt.title('Distribution of Cars by Body Style')
plt.axis('equal')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ###  Why Was the Pie Chart Used for "Distribution of Cars by Body Style"?
#
# A **pie chart** was specifically chosen for this visualization because the goal is to represent the **proportional distribution** of each car body style in the dataset. Since `body-style` is a **categorical variable** with a limited number of distinct values (like sedan, hatchback, wagon, etc.), a pie chart is an ideal and intuitive tool for this purpose.
#
# Here’s why the pie chart is well-suited for this analysis:
#
# 1. **Visualizing Proportions Clearly**
#    Pie charts are best used when we want to show how different parts (categories) make up a whole. In this case, each body style occupies a slice, and the viewer can instantly understand which styles are more or less common.
#
# 2. **Simple and Engaging**
#    The circular layout and distinct color segments make the chart visually appealing and easy to interpret—especially for non-technical audiences.
#
# 3. **Effective with Few Categories**
#    The number of unique body styles is limited, which avoids clutter and maintains readability—one of the key strengths of pie charts.
#
# 4. **Quick Business Insights**
#    By glancing at the chart, decision-makers can immediately assess which body styles are dominant in the market, aiding in inventory planning, marketing focus, or product development.
#
# Would you like the insights found from this chart as well?

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ###  Insights Found from the Chart: **Distribution of Cars by Body Style**
#
# 1. **Sedan is the Most Common Body Style**
#    The pie chart shows that **sedans occupy the largest slice**, indicating they are the most prevalent body style in the dataset. This suggests that sedans are likely a preferred choice among both **manufacturers** and **consumers**, possibly due to their balance of space, comfort, and affordability.
#
# 2. **Moderate Presence of Hatchbacks and Wagons**
#    Hatchbacks and wagons make up a **significant but smaller share**, implying they cater to more **specific use cases**, such as compact urban driving or added cargo space. These body styles may attract buyers looking for **utility** at a relatively lower price point.
#
# 3. **Niche Appeal for Convertibles and Hardtops**
#    Convertibles and hardtops form the **smallest slices** of the pie, reflecting their **limited market appeal**. These are typically **luxury or seasonal vehicles**, aimed at a niche segment seeking aesthetics and performance over practicality.
#
# 4. **Useful for Market Strategy**
#    The distribution helps businesses decide which body styles to **prioritize in production, marketing, and stock planning**, depending on their popularity and market demand.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ###  Will the Gained Insights Help Create a Positive Business Impact?
#
# Yes, the insights from the **“Distribution of Cars by Body Style”** pie chart can positively influence business strategy in several ways. First, identifying that **sedans dominate the market** allows manufacturers to **focus more on sedan production**, ensuring adequate inventory and marketing investments for the most in-demand segment. It also helps dealerships optimize floor space and advertising strategies by highlighting models that align with consumer preference. The **moderate demand for hatchbacks and wagons** suggests a solid opportunity in urban and family-focused markets, allowing companies to maintain a diverse yet efficient product lineup. Additionally, recognizing **niche body styles like convertibles and hardtops** helps brands develop premium offerings or seasonal marketing campaigns, catering to specific demographics without oversaturating the market.
#
# ---
#
# ###  Are There Any Insights That Lead to Negative Growth?
#
# Yes, if not interpreted correctly, these insights may lead to **strategic missteps**. For instance, over-reliance on sedans could make a company vulnerable to **market shifts**, such as a rising trend in SUVs or crossovers (not captured in this dataset). Neglecting body styles with lower representation—like hatchbacks or convertibles—might result in **missed niche opportunities**, especially in regions where compact or luxury lifestyle vehicles are gaining traction. Moreover, discontinuing slow-selling body styles based purely on volume may alienate **brand-loyal customers** or weaken the company’s **image as a full-range provider**. Therefore, businesses must combine volume insights with **trend forecasting** and **customer behavior analysis** to make balanced decisions that minimize negative impact.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
import seaborn as sns
import matplotlib.pyplot as plt

# Step 1: Select only numeric columns
numeric_df = df.select_dtypes(include='number')

# Step 2: Compute the correlation matrix
correlation_matrix = numeric_df.corr()

# Step 3: Plot heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Heatmap of Numeric Features')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ###  Why Was the Heatmap Used for "Correlation of Numeric Features"?
#
# A **heatmap** was specifically chosen for this analysis because it is the most effective way to **visually explore relationships** between multiple **numeric variables** at once. The correlation heatmap helps to quickly identify **positive or negative linear relationships** between features in a dataset like `price`, `horsepower`, `engine-size`, `curb-weight`, `mpg`, etc.
#
# Here's why the heatmap is ideal for this context:
#
# ---
#
# 1. **Multivariate Relationship Overview**
#    Unlike scatter plots or bar charts that compare two variables at a time, a heatmap enables you to **examine pairwise correlations** between **all numerical variables** simultaneously.
#
# 2. **Color Gradient Enhances Clarity**
#    The use of a color scale (`coolwarm`) makes it easy to **spot strong vs weak correlations**—warm colors (e.g., red) indicate strong positive correlation, while cool colors (e.g., blue) indicate strong negative correlation.
#
# 3. **Helps Identify Redundant or Predictive Features**
#    It quickly highlights variables that are highly correlated with the target variable (like `price`) or with each other, helping analysts make decisions around **feature selection**, **dimensionality reduction**, or **model simplification**.
#
# 4. **Essential for Data-Driven Insights**
#    Understanding which variables move together informs business and modeling strategies—for example, whether increasing engine size leads to higher prices or if fuel efficiency inversely relates to curb weight.
#
# 5. **Readable and Scalable**
#    Even with a large number of numerical features, the heatmap remains compact, intuitive, and easy to interpret with annotations (`annot=True`), aiding decision-making at a glance.
#
# ---
#
# Would you like the insights observed from this heatmap next?

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ###  Insights Found from the Heatmap: **Correlation of Numerical Features**
#
# 1. **Strong Positive Correlation Between Price and Performance Features**
#    The heatmap shows a **high positive correlation** between `price` and attributes like `engine-size`, `horsepower`, `curb-weight`, and `width`. This means that as these values increase, the **price of the vehicle also tends to rise**. These features likely represent **vehicle quality, power, and size**, which contribute to higher production cost and premium value.
#
# 2. **Strong Negative Correlation Between MPG and Price**
#    Both `city-mpg` and `highway-mpg` exhibit a **moderate negative correlation** with `price`, suggesting that **fuel-efficient cars tend to be less expensive**, while **less efficient vehicles (with lower MPG) are more costly**, likely due to larger engines and performance orientation.
#
# 3. **Redundancy Warning**
#    High correlations between `engine-size` and `horsepower`, as well as `curb-weight` and `width`, indicate **potential redundancy**. These variables may carry **similar information**, which is important to consider for **feature selection in predictive modeling**.
#
# 4. **Balanced Feature Relationships**
#    The heatmap also reveals **weak or no correlation** between some variables (like `peak-rpm` and `price`), showing that not all numerical features are useful predictors and could be excluded from complex analyses.
#
# ---
#
# Would you like these insights formatted into a paragraph for a report or presentation?

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Select relevant columns
pairplot_cols = ['price', 'horsepower', 'engine-size', 'city-mpg']

# Drop rows with missing values in these columns (optional for cleaner plot)
df_pair = df[pairplot_cols].dropna()

# Create pair plot
sns.pairplot(df_pair)
plt.suptitle('Pair Plot: Price vs Horsepower, Engine Size & City MPG', y=1.02)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ###  Why Did I Pick the Pair Plot for This Analysis?
#
# The **pair plot** was specifically chosen because it allows us to visualize **multiple relationships between numerical variables** in a single, compact graphic. In the context of automobile data, understanding how features like `price`, `horsepower`, `engine-size`, and `city-mpg` interact with one another is essential for uncovering **market patterns and performance trade-offs**.
#
# Here's why this chart was ideal:
#
# 1. **Multivariate Analysis in One View**
#    Unlike single-variable charts, the pair plot lets us compare **every possible pair** among the selected features, making it easier to spot meaningful trends.
#
# 2. **Detects Correlations & Outliers**
#    It highlights **linear and nonlinear relationships**, and reveals outliers—such as unusually high-priced cars with low horsepower.
#
# 3. **Comprehensive Yet Compact**
#    Instead of drawing multiple scatter plots separately, the pair plot **organizes all of them together**, saving space and enhancing clarity.
#
# 4. **Distribution Insights**
#    The diagonal plots show **individual feature distributions**, providing a better understanding of **feature spread and skewness**.
#
# This makes the pair plot an excellent tool for **feature selection, business insights**, and **pre-modeling analysis**.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ###  Insights Found from the Pair Plot (Price, Horsepower, Engine Size, City MPG)
#
# 1. **Strong Positive Correlation: Price vs Horsepower & Engine Size**
#    The pair plot clearly shows that as **horsepower and engine size increase**, the **price of the car also tends to rise**. This makes sense, as larger engines and more powerful cars are typically more expensive due to better performance, engineering, and brand positioning.
#
# 2. **Negative Correlation: Price vs City MPG**
#    There is a noticeable **negative relationship between price and city-mpg**. This implies that cars with higher fuel efficiency (more miles per gallon) tend to be **less expensive**, possibly because they are built for economy rather than performance.
#
# 3. **Horsepower vs Engine Size: High Internal Correlation**
#    These two features show a very tight linear relationship, indicating that **as engine size increases, horsepower almost always increases too**. This is expected, but it's useful when selecting features for modeling (one may be dropped to avoid redundancy).
#
# 4. **Feature Distributions on Diagonals**
#    The diagonal histograms show:
#
#    * `price` and `horsepower` are **right-skewed** (most cars are lower-priced/powered, a few are very high).
#    * `engine-size` is moderately right-skewed.
#    * `city-mpg` is roughly **normally distributed**, with most cars clustered around the mid-efficiency range.
#
# 5. **Potential Outliers**
#    Some cars show **extremely high prices** compared to others in the same horsepower/engine category—possibly **luxury or performance models**, which may deserve special attention in analysis.
#
# ---
#
# These insights help manufacturers and analysts understand how **performance, fuel economy, and price interact**, enabling better **product segmentation, pricing strategy, and marketing focus**.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.
# ###  Suggested Strategy to Achieve the Business Objective
#
# To achieve the business objective of understanding vehicle characteristics and aligning them with customer preferences for better pricing, production, and marketing decisions, I recommend the following:
#
# 1. **Segment the Market Based on Performance & Efficiency**
#    Use insights from correlations and visualizations to classify vehicles into categories such as economy, mid-range, and premium. For example, fuel-efficient cars with fewer cylinders and lower horsepower can be marketed to budget-conscious or eco-conscious customers, while vehicles with higher engine size, horsepower, and luxury features can be positioned as premium offerings.
#
# 2. **Optimize Product Mix**
#    Focus production on high-demand body styles like sedans and hatchbacks, but keep limited offerings in niche segments (e.g., convertibles) to attract specific buyers without overextending inventory.
#
# 3. **Price Models Strategically**
#    Leverage insights showing how price scales with features like engine size and horsepower. Offer flexible pricing tiers that align with perceived value and fuel efficiency.
#
# 4. **Improve Marketing Targeting**
#    Tailor marketing messages using customer-focused insights: promote affordability and mileage to mass-market buyers and emphasize performance or brand prestige to premium segments.
#
# By using data-driven insights, the client can make **smarter product, pricing, and marketing decisions**—leading to higher customer satisfaction and improved profitability.

# %% [markdown]
# Answer Here.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.
# ###  Conclusion
#
# The analysis of the automobile dataset has provided valuable insights into how various car features influence pricing, consumer demand, and market positioning. Through comprehensive data cleaning, transformation, and visualization, we uncovered meaningful relationships—such as the positive correlation between horsepower, engine size, and price, and the inverse relationship between fuel efficiency (MPG) and car cost. Visual tools like bar graphs, line plots, pie charts, and heatmaps effectively highlighted trends in car body styles, engine types, aspiration systems, and fuel systems, helping us understand customer preferences and product diversity.
#
# By segmenting vehicles based on performance and efficiency metrics, the findings enable better decision-making in product development, pricing strategies, and targeted marketing. Manufacturers and stakeholders can now align their offerings with specific customer needs—whether that be affordability, fuel economy, or luxury and performance.
#
# Overall, this data-driven approach equips the business with clear, actionable insights that can enhance customer satisfaction, optimize inventory, and drive long-term growth.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
